// %%
import org.apache.spark.sql.SparkSession
val spark:SparkSession = SparkSession.builder()
      .master("local[*]")
      .appName("Local spark")
      .getOrCreate()  

spark
// Out:
// spark = org.apache.spark.sql.SparkSession@6ab463e2
// org.apache.spark.sql.SparkSession@6ab463e2

// %%
val dataSeq = Seq(("Java", 20000), ("Python", 100000), ("Scala", 3000))   
val rdd=spark.sparkContext.parallelize(dataSeq)
rdd
// Out:
// dataSeq = List((Java,20000), (Python,100000), (Scala,3000))
// rdd = ParallelCollectionRDD[0] at parallelize at <console>:26
// ParallelCollectionRDD[0] at parallelize at <console>:26

// %%
rdd.collect()
// Out:
// Array((Java,20000), (Python,100000), (Scala,3000))
